# %% [markdown]
# ## Module submission header
# ### Submission preparation instructions
# _Completion of this header is mandatory, subject to a 2-point deduction to the assignment._ Only add plain text in the designated areas, i.e., replacing the relevant 'NA's. You must fill out all group member Names and Drexel email addresses in the below markdown list, under header __Module submission group__. It is required to fill out descriptive notes pertaining to any tutoring support received in the completion of this submission under the __Additional submission comments__ section at the bottom of the header. If no tutoring support was received, leave NA in place. You may as well list other optional comments pertaining to the submission at bottom. _Any distruption of this header's formatting will make your group liable to the 2-point deduction._
#
# ### Module submission group
# - Group member 1
#     - Name: Vishnu Ram Murali
#     - Email: vrm32@drexel.edu
# - Group member 2
#     - Name: Jeromey Abraham
#     - Email: jja99@drexel.edu
# - Group member 3
#     - Name: Mohamed Shehaf Aakil Sharfudeen
#     - Email: ms5475@drexel.edu
# - Group member 4
#     - Name: Jibin Joby
#     - Email: jj3225@drexel.edu
#
# ### Additional submission comments
# - Tutoring support received: NA
# - Other (other): NA

# %% [markdown]
# # Assignment group 1: Textual feature extraction and numerical comparison

# %% [markdown]
# ## Module A _(35 points)_ Processing numeric data

# %% [markdown]
# In this module, you will be working with the demographics data from The Henry J. Kaiser Family Foundation (https://www.kff.org/) including the population of 52 locations (50 states, District of Columbia, and Puerto Rico) based on race, gender, age, and the number of adults with and without children. This data is obtained from the Census Bureau’s American Community Survey (ACS). The data is stored in a `csv` file format located in the attached `data` directory.

# %% [markdown]
# __A1.__ Write a function called `get_shape_and_column` that accepts a string representing the path to the demographics.csv data. This function should read the provided csv data file into a pandas dataframe and then return a tuple with three things: the data frame (`data`), the shape of the data frame (`shape`), and a list of the columns (`columns`). (3 points)

# %%
# A1:Function(3/3)
# get_shape_and_column('./data/demographics.csv'):data,shape,column

import pandas as pd

def get_shape_and_columns(csv_path):
    
    #---Your code starts here---
    data = pd.read_csv(csv_path)
    shape = data.shape
    columns = data.columns
    #---Your code ends here---
    
    return data, shape, columns

# %% [markdown]
# __A2.__ _(2 points)_ To gain a better insight into the data, lets apply the function we just wrote to get our dataframe, inspect the shape and columns, and then look at the head and tail of this data (using the `.head()` and `.tail()` methods).

# %%
# A2:SanityCheck

# Load the data using our function
data, shape, columns = get_shape_and_columns('./data/demographics.csv')

# Output the shape and column names
print(shape)
print(columns)
# Out:
# (52, 18)
# Index(['Location', 'Male', 'Female', 'Adults_with_Children',
#        'Adults_with_No_Children', 'White', 'Black', 'Hispanic', 'Asian',
#        'American_Indian_or_Alaska_Native',
#        'Native_Hawaiian_or_Other_Pacific_Islander', 'Two_Or_More_Races',
#        'Age0_18', 'Age_19_25', 'Age_26_34', 'Age_35_54', 'Age_55_64',
#        'Age_65_plus'],
#       dtype='object')

# %%
# A2:SanityCheck

# Outputs the head of the data
data.head()
# Out:
#      Location      Male    Female  Adults_with_Children  \
# 0     Alabama   2284900   2456500                878300
# 1      Alaska    364500    345600                153600
# 2     Arizona   3363200   3478100               1322700
# 3    Arkansas   1422700   1487200                602000
# 4  California  19113000  19600800               7955200
#
#    Adults_with_No_Children     White      Black  Hispanic      Asian  \
# 0                  1941300   3119100  1259900.0    195700    63800.0
# 1                   283800    433000    18000.0     47400    46600.0
# 2                  2646700   3761600   270200.0   2143400   220300.0
# 3                  1096800   2109200   434100.0    220300    48100.0
# 4                 15981800  14305700  2061600.0  15194400  5598000.0
#
#    American_Indian_or_Alaska_Native  \
# 0                           19800.0
# 1                           95500.0
# 2                          261300.0
# 3                           13500.0
# 4                          138100.0
#
#    Native_Hawaiian_or_Other_Pacific_Islander  Two_Or_More_Races  Age0_18  \
# 0                                        NaN            81800.0  1138300
# 1                                     6300.0            63300.0   192300
# 2                                    12500.0           172000.0  1686200
# 3                                     7300.0            77500.0   730600
# 4                                   122900.0          1293200.0  9363800
#
#    Age_19_25  Age_26_34  Age_35_54  Age_55_64  Age_65_plus
# 0     430500   536200.0    1207200     645600       783600
# 1      63500    97900.0     183600      92400        80500
# 2     637200   815200.0    1677000     839900      1185700
# 3     265200   329800.0     726600     377100       480600
# 4    3697900  5240600.0   10277900    4720500      5413200

# %%
# A2:Inline(1/2)

# Which state is listed first in the head? Print the state name
# from this list of choices: (Alabama, Alaska, Arizona)

print("Alabama")
# Out:
# Alabama

# %%
# A2:SanityCheck

# Outputs the tail of the data
data.tail()
# Out:
#          Location     Male   Female  Adults_with_Children  \
# 47     Washington  3589700  3650100               1522400
# 48  West Virginia   863400   898700                322100
# 49      Wisconsin  2792400  2850600               1161900
# 50        Wyoming   286600   276700                118200
# 51    Puerto Rico  1570300  1734500                543200
#
#     Adults_with_No_Children    White     Black  Hispanic     Asian  \
# 47                  2920700  4976100  246900.0    916000  617900.0
# 48                   714100  1631600   64300.0     20400   14200.0
# 49                  2230900  4600500  328100.0    382000  166800.0
# 50                   214300   474400    5300.0     56100    4200.0
# 51                  1406500    23000       NaN   3274500       NaN
#
#     American_Indian_or_Alaska_Native  \
# 47                           68600.0
# 48                            2000.0
# 49                           43500.0
# 50                           12100.0
# 51                               NaN
#
#     Native_Hawaiian_or_Other_Pacific_Islander  Two_Or_More_Races  Age0_18  \
# 47                                    42200.0           372200.0  1701700
# 48                                        NaN            28800.0   385000
# 49                                        NaN           120600.0  1319600
# 50                                        NaN            11200.0   142400
# 51                                        NaN                NaN   701800
#
#     Age_19_25  Age_26_34  Age_35_54  Age_55_64  Age_65_plus
# 47     628700   965900.0    1899400     949100      1095000
# 48     148600   178300.0     448700     260600       340900
# 49     495600   643300.0    1441400     812500       930500
# 50      48500    69400.0     133100      81500        88300
# 51     327600   344300.0     849600     428200       653200

# %%
# A2:Inline(1/2)

# Which state is listed first in the tail? Print the state name
# from this list of choices: (Wyoming, Puerto Rico, Washington)
print("Washington")
# Out:
# Washington

# %% [markdown]
# __A3.__ _(5 points)_ As you can see, there is no `total` population column in this dataframe for each location. Therefore, let's write a function called `total_columns` that takes a dataframe and two column names and returns an updated dataframe. This function should create a new column in the provided dataframe called `total` that is the sum of the data in the two provided columns. It should return this updated data frame.

# %%
# A3:Function(3/5)
# total_columns('./data/demographics.csv', "Male", "Female")

def total_columns(data, column1, column2):
    
    #---Your code starts here---
    data['total'] = data[column1] + data[column2]
    #---Your code ends here---
    
    return data

# %% [markdown]
# To test your function, let's apply it to create totals for some of the fields and inspect at the results.
#
# The pandas package provides a `.describe()` method which gives a descriptive summary of the desired column(s) (such as mean, standard deviation, min, and max values). The following code cells print these statistics for the newly created `total` columns.

# %%
# A3:SanityCheck

# Creates a total column for ages 35-64
data = total_columns(data, "Age_35_54", "Age_55_64")

# Uses the describe method to show the summary statistics for the newly created 'total' column
data[['total']].describe()
# Out:
#               total
# count  5.200000e+01
# mean   2.408640e+06
# std    2.750352e+06
# min    2.146000e+05
# 25%    6.786000e+05
# 50%    1.652950e+06
# 75%    2.727825e+06
# max    1.499840e+07

# %%
# A3:SanityCheck

# Creates a total column for ages 19-34
data = total_columns(data, "Age_19_25", "Age_26_34")

# Uses the describe method to show the summary statistics for the newly created 'total' column
data[['total']].describe()
# Out:
#               total
# count  5.200000e+01
# mean   1.309954e+06
# std    1.584595e+06
# min    1.179000e+05
# 25%    3.369500e+05
# 50%    8.690500e+05
# 75%    1.487950e+06
# max    8.938500e+06

# %%
# A3:Inline(2/5)

# Which mean total is greater, the sum of Age_35_54 + Age_55_64 or the sum of Age_19_25 + Age_26_34?
# Print either "Older" or "Younger"

print("Older")
# Out:
# Older

# %%
datamax = data.loc[data['total'].idxmax()]
datamax[0]
# Out:
# 'California'

# %% [markdown]
# __A4:__ _(5 points)_ Next, write a function that takes a dataframe that has a `total` column and returns a tuple with four values: the location with the minimum total (`min_location`), the total for that min location (`min_total`), the location with the maximum total (`max_location`), and the total for the max location (`max_total`). Note that the locations returned should correspond to specific states (e.g., `"Alabama"`) and the totals should be numbers (e.g., `23000`)

# %%
# A4:Function(4/5)

def get_min_max_locations(data):
    
    #---Your code starts here---
    min_location = data.loc[data["total"].idxmin(), "Location"]
    min_total = data.loc[data["total"].idxmin(), "total"]
    max_location = data.loc[data["total"].idxmax(), "Location"]
    max_total = data.loc[data["total"].idxmax(), "total"]
    #---Your code ends here---
    
    return min_location, min_total, max_location, max_total

# %% [markdown]
# Let's apply the functions you have created to (1) total up the male and female population counts and (2) identify the states with the minimum and maximum totals and their total amounts.

# %%
# A4:SanityCheck

# Create a total column that contains Male + Female
data = total_columns(data, "Male", "Female")

# Get the min and max states
min_loc, min_total, max_loc, max_total = get_min_max_locations(data)

print("Minimum location: {} (total={})".format(min_loc, min_total))
print("Maximum location: {} (total={})".format(max_loc, max_total))
# Out:
# Minimum location: Wyoming (total=563300)
# Maximum location: California (total=38713800)

# %%
# A4:Inline(1/5)

# Print the state with the smallest total (make sure to get capitalization right)?
print("Wyoming")
# Out:
# Wyoming

# %% [markdown]
# __A5.__ _(5 points)_ Our previous `total_columns` function has some limitations. First, it only lets us create a total column that is the sum of two columns. Additionally, it always names the resulting column `total`. Please write an updated `total_columns` function that takes three arguments: `data` (a dataframe), `list_of_columns` (a list of columns to total), and `total_name` (a name for the resulting total column). This function should total the values across all the columns in `list_of_columns` and put the result in the target `total_name` column.

# %%
# A5:Function(4/5)
def total_columns(data, list_of_columns, total_name="total"):
    #---Your code starts here---
    data[total_name] = data[list_of_columns].sum(axis=1)
    #---Your code ends here---
    return data

# %% [markdown]
# To test the function you've created, let's apply it to investigate our data. In particular, let's look at two columns `Adults_with_Children` and `Adults_with_No_Children`. It seems that the populations in these two columns do not include the children (aged younger than 18 years), and older adults (aged older than 64 years). To confirm this hypothesis, let's use our new `total_columns` function to create two total columns and then compare them. We will then look to see if there is a difference between these totals for three states: `Pennsylvania`, `Colorado`, and `Georgia`.

# %%
# A5:SanityCheck

# Create a total for all the adult age groups (excluding people youger than 18 or older than 64)
adult_age_group_columns = ['Age_19_25', 'Age_26_34', 'Age_35_54', 'Age_55_64']
data = total_columns(data, adult_age_group_columns, "total_adult_age_groups")

# Create a total column for adults with and without children.
adults_columns = ['Adults_with_Children', 'Adults_with_No_Children']
data = total_columns(data, adults_columns, "total_adults")

# Compute the difference between these values
data['diff'] = data['total_adult_age_groups'] - data['total_adults']

# Look at the differences for Pennsylvania, Colorado, and Georgia
print("Pennsylvania difference: {}".format(data[data['Location'] == "Pennsylvania"]['diff'].values))
print("Colorado difference: {}".format(data[data['Location'] == "Colorado"]['diff'].values))
print("Georgia difference: {}".format(data[data['Location'] == "Georgia"]['diff'].values))
# Out:
# Pennsylvania difference: [0.]
# Colorado difference: [0.]
# Georgia difference: [0.]

# %%
# A5:Inline(1/5)

# Is there a difference for these three states? Print "Yes" or "No"
print("No")
# Out:
# No

# %% [markdown]
# __A6:__ _(2 points)_ To investigate our hypothesis more generally, write a function called `are_columns_equal` that takes a dataframe and two columns names (for two columns we want to compare). The function should return a boolean value `are_equal` that is True if all the values for the two columns are the same and False if there is at least one difference.

# %%
# A6:Function(2/2)

def are_columns_equal(data, column1, column2):
    
    #---Your code starts here---
    are_equal = (data[column1] == data[column2]).all()
    #---Your code starts here---
    
    return are_equal

# %% [markdown]
# To test this function, let's apply it to test our hypothesis that`total_adult_age_groups` and `total_adults` are the same for all locations.

# %%
# A6:SanityCheck

print(are_columns_equal(data, 'total_adult_age_groups', 'total_adults'))
# Out:
# False

# %% [markdown]
# __A7:__ _(3 points)_ It seems that our hypothesis is not correct for all the locations. To investigate further, create a function called `get_location_difference_dict` that takes a dataframe and two column names and returns a dictionary (`location_diff_dict`) that has locations for keys and the difference (column1 value - column2 value) as values. Additionally, the dictionary should only include values for entries that have a non-zero difference (places where column1 value != column2 value).
#
# For example, the resulting dictionary should look something like this:
# ```
# {'Alabama': 300,
#  'California': -210,
#  ...
# }
# ```

# %%
# A7:Function(2/3)

def get_location_difference_dict(data, column1, column2):
    
    #---Your code starts here---
    location_diff_dict = {}
    locations = data['Location']
    column1_val = data[column1].values
    column2_val = data[column2].values
    for i in range(len(locations)):
        location = locations[i]
        diff = column1_val[i] - column2_val[i]
        if diff != 0:
            location_diff_dict[location] = diff
    #---Your code ends here---
    
    return location_diff_dict

# %% [markdown]
# Now let's apply the function you have created to see what the differences in `total_adult_age_groups` and `total_adults` look like across our data.

# %%
# A7:SanityCheck
get_location_difference_dict(data,'total_adult_age_groups', 'total_adults')
# Out:
# {'Alabama': -100.0,
#  'Arizona': -100.0,
#  'Arkansas': -100.0,
#  'California': -100.0,
#  'Delaware': -100.0,
#  'Florida': -100.0,
#  'Idaho': 100.0,
#  'Illinois': 100.0,
#  'Iowa': 100.0,
#  'Kansas': -100.0,
#  'Kentucky': -100.0,
#  'Louisiana': -100.0,
#  'Minnesota': -100.0,
#  'Montana': 100.0,
#  'Nebraska': -100.0,
#  'New Mexico': 100.0,
#  'North Carolina': -200.0,
#  'North Dakota': -100.0,
#  'Oklahoma': 100.0,
#  'Oregon': 100.0,
#  'South Carolina': -100.0,
#  'Utah': -100.0,
#  'Vermont': 100.0,
#  'Virginia': -200.0}

# %%
# A7:Inline(1/3)

# Print the name of the state with the larger difference (greater absolute magnitude),
# "Alabama" or "North Carolina"?
print("North Carolina")
# Out:
# North Carolina

# %% [markdown]
# __A8.__ _(7 points)_ In this problem, we are going to investigate the similarity of locations using _cosine similarity_. To support these investigations, write a function called `compute_cosine_similarity` that takes a dataframe (`data`) and a list of column names (`similarity_columns`) to use when computing the cosine similarity. This function should use the provided `similarity_columns` to compute the cosine similiarity between each pair of locations. In cases where there is no population for one of the provided columns for a location in the dataframe (the corresponding value is `NaN`), replace them with `zero` using the `.fillna()` method of pandas. This function should return a list of tuples (`similarity_list`) with the following format `(<location 1>, <location 2>, <cosine similarity between them>)`.
#
# Here is an example of what the output from this function should look like:
# ```
# [('Alabama', 'Alaska', 0.223890893223),
#  ('Alabama', 'Arizona', 0.43432273237),
#  ('Alabama', 'Arkansas', 0.112312121213),
#  ('Alabama', 'California', 0.45645645654623),
#  ('Alabama', 'Colorado', 0.234616734),
#  ('Alabama', 'Connecticut', 0.676533422),
#  ('Alabama', 'Delaware', 0.1234645667),
#  ...
# ]
# ```
#
# Note that each pair of locations will appear twice in this list in different orders; e.g., `('Alabama', 'Alaska', 223890893223)` and `('Alaska', 'Alabama', 223890893223)` will both appear.

# %%
# A8:Function(7/7)
import numpy as np
from scipy.spatial.distance import cosine

def compute_cosine_similarity(data, similarity_columns):
    
    #---Your code starts here
    similarity_list = []
    data[similarity_columns].fillna(0, inplace=True)
    
    for i, loc1 in enumerate(data['Location']):
        for j, loc2 in enumerate(data['Location'][i+1:]):
            loc1_vector = data[data['Location'] == loc1][similarity_columns].values[0]
            loc2_vector = data[data['Location'] == loc2][similarity_columns].values[0]
            cos_sim = 1 - cosine(loc1_vector, loc2_vector)
            similarity_list.append((loc1, loc2, cos_sim))
            similarity_list.append((loc2, loc1, cos_sim))
    #---Your code ends here

    return similarity_list

# %% [markdown]
# To test our function, lets apply it to compare locations according to both race and age demographics.

# %%
# A8:SanityCheck

# All the race columns
race_columns = ['White', 'Black', 'Hispanic', 'Asian', 'American_Indian_or_Alaska_Native', \
                'Native_Hawaiian_or_Other_Pacific_Islander', 'Two_Or_More_Races']

race_similarity = compute_cosine_similarity(data, race_columns)
race_similarity
# Out:
# /var/folders/bt/_bxgcdhj6z3_nfpmnzbyygj00000gn/T/ipykernel_68072/247036547.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[similarity_columns].fillna(0, inplace=True)
# [('Alabama', 'Alaska', 1),
#  ('Alaska', 'Alabama', 1),
#  ('Alabama', 'Arizona', 1),
#  ('Arizona', 'Alabama', 1),
#  ('Alabama', 'Arkansas', 1),
#  ('Arkansas', 'Alabama', 1),
#  ('Alabama', 'California', 1),
#  ('California', 'Alabama', 1),
#  ('Alabama', 'Colorado', 1),
#  ('Colorado', 'Alabama', 1),
#  ('Alabama', 'Connecticut', 1),
#  ('Connecticut', 'Alabama', 1),
#  ('Alabama', 'Delaware', 1),
#  ('Delaware', 'Alabama', 1),
#  ('Alabama', 'District of Columbia', 1),
#  ('District of Columbia', 'Alabama', 1),
#  ('Alabama', 'Florida', 1),
#  ('Florida', 'Alabama', 1),
#  ('Alabama', 'Georgia', 1),
#  ('Georgia', 'Alabama', 1),
#  ('Alabama', 'Hawaii', 1),
#  ('Hawaii', 'Alabama', 1),
#  ('Alabama', 'Idaho', 1),
#  ('Idaho', 'Alabama', 1),
#  ('Alabama', 'Illinois', 1),
#  ('Illinois', 'Alabama', 1),
#  ('Alabama', 'Indiana', 1),
#  ('Indiana', 'Alabama', 1),
#  ('Alabama', 'Iowa', 1),
#  ('Iowa', 'Alabama', 1),
#  ('Alabama', 'Kansas', 1),
#  ('Kansas', 'Alabama', 1),
#  ('Alabama', 'Kentucky', 1),
#  ('Kentucky', 'Alabama', 1),
#  ('Alabama', 'Louisiana', 1),
#  ('Louisiana', 'Alabama', 1),
#  ('Alabama', 'Maine', 1),
#  ('Maine', 'Alabama', 1),
#  ('Alabama', 'Maryland', 1),
#  ('Maryland', 'Alabama', 1),
#  ('Alabama', 'Massachusetts', 1),
#  ('Massachusetts', 'Alabama', 1),
#  ('Alabama', 'Michigan', 1),
#  ('Michigan', 'Alabama', 1),
#  ('Alabama', 'Minnesota', 1),
#  ('Minnesota', 'Alabama', 1),
#  ('Alabama', 'Mississippi', 1),
#  ('Mississippi', 'Alabama', 1),
#  ('Alabama', 'Missouri', 1),
#  ('Missouri', 'Alabama', 1),
#  ('Alabama', 'Montana', 1),
#  ('Montana', 'Alabama', 1),
#  ('Alabama', 'Nebraska', 1),
#  ('Nebraska', 'Alabama', 1),
#  ('Alabama', 'Nevada', 1),
#  ('Nevada', 'Alabama', 1),
#  ('Alabama', 'New Hampshire', 1),
#  ('New Hampshire', 'Alabama', 1),
#  ('Alabama', 'New Jersey', 1),
#  ('New Jersey', 'Alabama', 1),
#  ('Alabama', 'New Mexico', 1),
#  ('New Mexico', 'Alabama', 1),
#  ('Alabama', 'New York', 1),
#  ('New York', 'Alabama', 1),
#  ('Alabama', 'North Carolina', 1),
#  ('North Carolina', 'Alabama', 1),
#  ('Alabama', 'North Dakota', 1),
#  ('North Dakota', 'Alabama', 1),
#  ('Alabama', 'Ohio', 1),
#  ('Ohio', 'Alabama', 1),
#  ('Alabama', 'Oklahoma', 1),
#  ('Oklahoma', 'Alabama', 1),
#  ('Alabama', 'Oregon', 1),
#  ('Oregon', 'Alabama', 1),
#  ('Alabama', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Alabama', 1),
#  ('Alabama', 'Rhode Island', 1),
#  ('Rhode Island', 'Alabama', 1),
#  ('Alabama', 'South Carolina', 1),
#  ('South Carolina', 'Alabama', 1),
#  ('Alabama', 'South Dakota', 1),
#  ('South Dakota', 'Alabama', 1),
#  ('Alabama', 'Tennessee', 1),
#  ('Tennessee', 'Alabama', 1),
#  ('Alabama', 'Texas', 1),
#  ('Texas', 'Alabama', 1),
#  ('Alabama', 'Utah', 1),
#  ('Utah', 'Alabama', 1),
#  ('Alabama', 'Vermont', 1),
#  ('Vermont', 'Alabama', 1),
#  ('Alabama', 'Virginia', 1),
#  ('Virginia', 'Alabama', 1),
#  ('Alabama', 'Washington', 1),
#  ('Washington', 'Alabama', 1),
#  ('Alabama', 'West Virginia', 1),
#  ('West Virginia', 'Alabama', 1),
#  ('Alabama', 'Wisconsin', 1),
#  ('Wisconsin', 'Alabama', 1),
#  ('Alabama', 'Wyoming', 1),
#  ('Wyoming', 'Alabama', 1),
#  ('Alabama', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Alabama', 1),
#  ('Alaska', 'Arizona', 0.9026314648157776),
#  ('Arizona', 'Alaska', 0.9026314648157776),
#  ('Alaska', 'Arkansas', 0.957318497139711),
#  ('Arkansas', 'Alaska', 0.957318497139711),
#  ('Alaska', 'California', 0.7416111800267029),
#  ('California', 'Alaska', 0.7416111800267029),
#  ('Alaska', 'Colorado', 0.9529090361921408),
#  ('Colorado', 'Alaska', 0.9529090361921408),
#  ('Alaska', 'Connecticut', 1),
#  ('Connecticut', 'Alaska', 1),
#  ('Alaska', 'Delaware', 1),
#  ('Delaware', 'Alaska', 1),
#  ('Alaska', 'District of Columbia', 1),
#  ('District of Columbia', 'Alaska', 1),
#  ('Alaska', 'Florida', 0.8979329300291787),
#  ('Florida', 'Alaska', 0.8979329300291787),
#  ('Alaska', 'Georgia', 1),
#  ('Georgia', 'Alaska', 1),
#  ('Alaska', 'Hawaii', 0.5558277164519617),
#  ('Hawaii', 'Alaska', 0.5558277164519617),
#  ('Alaska', 'Idaho', 1),
#  ('Idaho', 'Alaska', 1),
#  ('Alaska', 'Illinois', 1),
#  ('Illinois', 'Alaska', 1),
#  ('Alaska', 'Indiana', 1),
#  ('Indiana', 'Alaska', 1),
#  ('Alaska', 'Iowa', 1),
#  ('Iowa', 'Alaska', 1),
#  ('Alaska', 'Kansas', 1),
#  ('Kansas', 'Alaska', 1),
#  ('Alaska', 'Kentucky', 1),
#  ('Kentucky', 'Alaska', 1),
#  ('Alaska', 'Louisiana', 1),
#  ('Louisiana', 'Alaska', 1),
#  ('Alaska', 'Maine', 1),
#  ('Maine', 'Alaska', 1),
#  ('Alaska', 'Maryland', 0.8661491682809546),
#  ('Maryland', 'Alaska', 0.8661491682809546),
#  ('Alaska', 'Massachusetts', 1),
#  ('Massachusetts', 'Alaska', 1),
#  ('Alaska', 'Michigan', 1),
#  ('Michigan', 'Alaska', 1),
#  ('Alaska', 'Minnesota', 1),
#  ('Minnesota', 'Alaska', 1),
#  ('Alaska', 'Mississippi', 1),
#  ('Mississippi', 'Alaska', 1),
#  ('Alaska', 'Missouri', 0.9630283412373563),
#  ('Missouri', 'Alaska', 0.9630283412373563),
#  ('Alaska', 'Montana', 1),
#  ('Montana', 'Alaska', 1),
#  ('Alaska', 'Nebraska', 1),
#  ('Nebraska', 'Alaska', 1),
#  ('Alaska', 'Nevada', 0.8874290078701619),
#  ('Nevada', 'Alaska', 0.8874290078701619),
#  ('Alaska', 'New Hampshire', 1),
#  ('New Hampshire', 'Alaska', 1),
#  ('Alaska', 'New Jersey', 1),
#  ('New Jersey', 'Alaska', 1),
#  ('Alaska', 'New Mexico', 1),
#  ('New Mexico', 'Alaska', 1),
#  ('Alaska', 'New York', 0.9303033650880929),
#  ('New York', 'Alaska', 0.9303033650880929),
#  ('Alaska', 'North Carolina', 0.9361053969669315),
#  ('North Carolina', 'Alaska', 0.9361053969669315),
#  ('Alaska', 'North Dakota', 1),
#  ('North Dakota', 'Alaska', 1),
#  ('Alaska', 'Ohio', 0.9615100295026753),
#  ('Ohio', 'Alaska', 0.9615100295026753),
#  ('Alaska', 'Oklahoma', 0.988178033986043),
#  ('Oklahoma', 'Alaska', 0.988178033986043),
#  ('Alaska', 'Oregon', 0.972416426095755),
#  ('Oregon', 'Alaska', 0.972416426095755),
#  ('Alaska', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Alaska', 1),
#  ('Alaska', 'Rhode Island', 1),
#  ('Rhode Island', 'Alaska', 1),
#  ('Alaska', 'South Carolina', 1),
#  ('South Carolina', 'Alaska', 1),
#  ('Alaska', 'South Dakota', 1),
#  ('South Dakota', 'Alaska', 1),
#  ('Alaska', 'Tennessee', 1),
#  ('Tennessee', 'Alaska', 1),
#  ('Alaska', 'Texas', 0.7690879670609413),
#  ('Texas', 'Alaska', 0.7690879670609413),
#  ('Alaska', 'Utah', 0.9680797021853659),
#  ('Utah', 'Alaska', 0.9680797021853659),
#  ('Alaska', 'Vermont', 1),
#  ('Vermont', 'Alaska', 1),
#  ('Alaska', 'Virginia', 0.944510215952208),
#  ('Virginia', 'Alaska', 0.944510215952208),
#  ('Alaska', 'Washington', 0.9751679121530704),
#  ('Washington', 'Alaska', 0.9751679121530704),
#  ('Alaska', 'West Virginia', 1),
#  ('West Virginia', 'Alaska', 1),
#  ('Alaska', 'Wisconsin', 1),
#  ('Wisconsin', 'Alaska', 1),
#  ('Alaska', 'Wyoming', 1),
#  ('Wyoming', 'Alaska', 1),
#  ('Alaska', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Alaska', 1),
#  ('Arizona', 'Arkansas', 0.9063079846094056),
#  ('Arkansas', 'Arizona', 0.9063079846094056),
#  ('Arizona', 'California', 0.9338928225441735),
#  ('California', 'Arizona', 0.9338928225441735),
#  ('Arizona', 'Colorado', 0.9764531765527142),
#  ('Colorado', 'Arizona', 0.9764531765527142),
#  ('Arizona', 'Connecticut', 1),
#  ('Connecticut', 'Arizona', 1),
#  ('Arizona', 'Delaware', 1),
#  ('Delaware', 'Arizona', 1),
#  ('Arizona', 'District of Columbia', 1),
#  ('District of Columbia', 'Arizona', 1),
#  ('Arizona', 'Florida', 0.9788987938922208),
#  ('Florida', 'Arizona', 0.9788987938922208),
#  ('Arizona', 'Georgia', 1),
#  ('Georgia', 'Arizona', 1),
#  ('Arizona', 'Hawaii', 0.514301367497454),
#  ('Hawaii', 'Arizona', 0.514301367497454),
#  ('Arizona', 'Idaho', 1),
#  ('Idaho', 'Arizona', 1),
#  ('Arizona', 'Illinois', 1),
#  ('Illinois', 'Arizona', 1),
#  ('Arizona', 'Indiana', 1),
#  ('Indiana', 'Arizona', 1),
#  ('Arizona', 'Iowa', 1),
#  ('Iowa', 'Arizona', 1),
#  ('Arizona', 'Kansas', 1),
#  ('Kansas', 'Arizona', 1),
#  ('Arizona', 'Kentucky', 1),
#  ('Kentucky', 'Arizona', 1),
#  ('Arizona', 'Louisiana', 1),
#  ('Louisiana', 'Arizona', 1),
#  ('Arizona', 'Maine', 1),
#  ('Maine', 'Arizona', 1),
#  ('Arizona', 'Maryland', 0.8539487063405387),
#  ('Maryland', 'Arizona', 0.8539487063405387),
#  ('Arizona', 'Massachusetts', 1),
#  ('Massachusetts', 'Arizona', 1),
#  ('Arizona', 'Michigan', 1),
#  ('Michigan', 'Arizona', 1),
#  ('Arizona', 'Minnesota', 1),
#  ('Minnesota', 'Arizona', 1),
#  ('Arizona', 'Mississippi', 1),
#  ('Mississippi', 'Arizona', 1),
#  ('Arizona', 'Missouri', 0.8905241098238862),
#  ('Missouri', 'Arizona', 0.8905241098238862),
#  ('Arizona', 'Montana', 1),
#  ('Montana', 'Arizona', 1),
#  ('Arizona', 'Nebraska', 1),
#  ('Nebraska', 'Arizona', 1),
#  ('Arizona', 'Nevada', 0.990192434224619),
#  ('Nevada', 'Arizona', 0.990192434224619),
#  ('Arizona', 'New Hampshire', 1),
#  ('New Hampshire', 'Arizona', 1),
#  ('Arizona', 'New Jersey', 1),
#  ('New Jersey', 'Arizona', 1),
#  ('Arizona', 'New Mexico', 1),
#  ('New Mexico', 'Arizona', 1),
#  ('Arizona', 'New York', 0.9631984826307989),
#  ('New York', 'Arizona', 0.9631984826307989),
#  ('Arizona', 'North Carolina', 0.9029150567804026),
#  ('North Carolina', 'Arizona', 0.9029150567804026),
#  ('Arizona', 'North Dakota', 1),
#  ('North Dakota', 'Arizona', 1),
#  ('Arizona', 'Ohio', 0.8872259176389972),
#  ('Ohio', 'Arizona', 0.8872259176389972),
#  ('Arizona', 'Oklahoma', 0.9331573076004651),
#  ('Oklahoma', 'Arizona', 0.9331573076004651),
#  ('Arizona', 'Oregon', 0.9386690744217069),
#  ('Oregon', 'Arizona', 0.9386690744217069),
#  ('Arizona', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Arizona', 1),
#  ('Arizona', 'Rhode Island', 1),
#  ('Rhode Island', 'Arizona', 1),
#  ('Arizona', 'South Carolina', 1),
#  ('South Carolina', 'Arizona', 1),
#  ('Arizona', 'South Dakota', 1),
#  ('South Dakota', 'Arizona', 1),
#  ('Arizona', 'Tennessee', 1),
#  ('Tennessee', 'Arizona', 1),
#  ('Arizona', 'Texas', 0.9608864884780945),
#  ('Texas', 'Arizona', 0.9608864884780945),
#  ('Arizona', 'Utah', 0.9397720414558244),
#  ('Utah', 'Arizona', 0.9397720414558244),
#  ('Arizona', 'Vermont', 1),
#  ('Vermont', 'Arizona', 1),
#  ('Arizona', 'Virginia', 0.9084825331987362),
#  ('Virginia', 'Arizona', 0.9084825331987362),
#  ('Arizona', 'Washington', 0.9408473413271422),
#  ('Washington', 'Arizona', 0.9408473413271422),
#  ('Arizona', 'West Virginia', 1),
#  ('West Virginia', 'Arizona', 1),
#  ('Arizona', 'Wisconsin', 1),
#  ('Wisconsin', 'Arizona', 1),
#  ('Arizona', 'Wyoming', 1),
#  ('Wyoming', 'Arizona', 1),
#  ('Arizona', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Arizona', 1),
#  ('Arkansas', 'California', 0.7384153531926173),
#  ('California', 'Arkansas', 0.7384153531926173),
#  ('Arkansas', 'Colorado', 0.9687218582307588),
#  ('Colorado', 'Arkansas', 0.9687218582307588),
#  ('Arkansas', 'Connecticut', 1),
#  ('Connecticut', 'Arkansas', 1),
#  ('Arkansas', 'Delaware', 1),
#  ('Delaware', 'Arkansas', 1),
#  ('Arkansas', 'District of Columbia', 1),
#  ('District of Columbia', 'Arkansas', 1),
#  ('Arkansas', 'Florida', 0.9437253538832346),
#  ('Florida', 'Arkansas', 0.9437253538832346),
#  ('Arkansas', 'Georgia', 1),
#  ('Georgia', 'Arkansas', 1),
#  ('Arkansas', 'Hawaii', 0.459765866819664),
#  ('Hawaii', 'Arkansas', 0.459765866819664),
#  ('Arkansas', 'Idaho', 1),
#  ('Idaho', 'Arkansas', 1),
#  ('Arkansas', 'Illinois', 1),
#  ('Illinois', 'Arkansas', 1),
#  ('Arkansas', 'Indiana', 1),
#  ('Indiana', 'Arkansas', 1),
#  ('Arkansas', 'Iowa', 1),
#  ('Iowa', 'Arkansas', 1),
#  ('Arkansas', 'Kansas', 1),
#  ('Kansas', 'Arkansas', 1),
#  ('Arkansas', 'Kentucky', 1),
#  ('Kentucky', 'Arkansas', 1),
#  ('Arkansas', 'Louisiana', 1),
#  ('Louisiana', 'Arkansas', 1),
#  ('Arkansas', 'Maine', 1),
#  ('Maine', 'Arkansas', 1),
#  ('Arkansas', 'Maryland', 0.9444561246076086),
#  ('Maryland', 'Arkansas', 0.9444561246076086),
#  ('Arkansas', 'Massachusetts', 1),
#  ('Massachusetts', 'Arkansas', 1),
#  ('Arkansas', 'Michigan', 1),
#  ('Michigan', 'Arkansas', 1),
#  ('Arkansas', 'Minnesota', 1),
#  ('Minnesota', 'Arkansas', 1),
#  ('Arkansas', 'Mississippi', 1),
#  ('Mississippi', 'Arkansas', 1),
#  ('Arkansas', 'Missouri', 0.996678383809116),
#  ('Missouri', 'Arkansas', 0.996678383809116),
#  ('Arkansas', 'Montana', 1),
#  ('Montana', 'Arkansas', 1),
#  ('Arkansas', 'Nebraska', 1),
#  ('Nebraska', 'Arkansas', 1),
#  ('Arkansas', 'Nevada', 0.9040322973076695),
#  ('Nevada', 'Arkansas', 0.9040322973076695),
#  ('Arkansas', 'New Hampshire', 1),
#  ('New Hampshire', 'Arkansas', 1),
#  ('Arkansas', 'New Jersey', 1),
#  ('New Jersey', 'Arkansas', 1),
#  ('Arkansas', 'New Mexico', 1),
#  ('New Mexico', 'Arkansas', 1),
#  ('Arkansas', 'New York', 0.9667150960608604),
#  ('New York', 'Arkansas', 0.9667150960608604),
#  ('Arkansas', 'North Carolina', 0.9921883826820536),
#  ('North Carolina', 'Arkansas', 0.9921883826820536),
#  ('Arkansas', 'North Dakota', 1),
#  ('North Dakota', 'Arkansas', 1),
#  ('Arkansas', 'Ohio', 0.9970475723935807),
#  ('Ohio', 'Arkansas', 0.9970475723935807),
#  ('Arkansas', 'Oklahoma', 0.9860906413679661),
#  ('Oklahoma', 'Arkansas', 0.9860906413679661),
#  ('Arkansas', 'Oregon', 0.9811339789856848),
#  ('Oregon', 'Arkansas', 0.9811339789856848),
#  ('Arkansas', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Arkansas', 1),
#  ('Arkansas', 'Rhode Island', 1),
#  ('Rhode Island', 'Arkansas', 1),
#  ('Arkansas', 'South Carolina', 1),
#  ('South Carolina', 'Arkansas', 1),
#  ('Arkansas', 'South Dakota', 1),
#  ('South Dakota', 'Arkansas', 1),
#  ('Arkansas', 'Tennessee', 1),
#  ('Tennessee', 'Arkansas', 1),
#  ('Arkansas', 'Texas', 0.8008147633216119),
#  ('Texas', 'Arkansas', 0.8008147633216119),
#  ('Arkansas', 'Utah', 0.9797350705352691),
#  ('Utah', 'Arkansas', 0.9797350705352691),
#  ('Arkansas', 'Vermont', 1),
#  ('Vermont', 'Arkansas', 1),
#  ('Arkansas', 'Virginia', 0.992228469585691),
#  ('Virginia', 'Arkansas', 0.992228469585691),
#  ('Arkansas', 'Washington', 0.9798654988236942),
#  ('Washington', 'Arkansas', 0.9798654988236942),
#  ('Arkansas', 'West Virginia', 1),
#  ('West Virginia', 'Arkansas', 1),
#  ('Arkansas', 'Wisconsin', 1),
#  ('Wisconsin', 'Arkansas', 1),
#  ('Arkansas', 'Wyoming', 1),
#  ('Wyoming', 'Arkansas', 1),
#  ('Arkansas', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Arkansas', 1),
#  ('California', 'Colorado', 0.8539076847466507),
#  ('Colorado', 'California', 0.8539076847466507),
#  ('California', 'Connecticut', 1),
#  ('Connecticut', 'California', 1),
#  ('California', 'Delaware', 1),
#  ('Delaware', 'California', 1),
#  ('California', 'District of Columbia', 1),
#  ('District of Columbia', 'California', 1),
#  ('California', 'Florida', 0.903373501122792),
#  ('Florida', 'California', 0.903373501122792),
#  ('California', 'Georgia', 1),
#  ('Georgia', 'California', 1),
#  ('California', 'Hawaii', 0.6386269797658789),
#  ('Hawaii', 'California', 0.6386269797658789),
#  ('California', 'Idaho', 1),
#  ('Idaho', 'California', 1),
#  ('California', 'Illinois', 1),
#  ('Illinois', 'California', 1),
#  ('California', 'Indiana', 1),
#  ('Indiana', 'California', 1),
#  ('California', 'Iowa', 1),
#  ('Iowa', 'California', 1),
#  ('California', 'Kansas', 1),
#  ('Kansas', 'California', 1),
#  ('California', 'Kentucky', 1),
#  ('Kentucky', 'California', 1),
#  ('California', 'Louisiana', 1),
#  ('Louisiana', 'California', 1),
#  ('California', 'Maine', 1),
#  ('Maine', 'California', 1),
#  ('California', 'Maryland', 0.7540231805966129),
#  ('Maryland', 'California', 0.7540231805966129),
#  ('California', 'Massachusetts', 1),
#  ('Massachusetts', 'California', 1),
#  ('California', 'Michigan', 1),
#  ('Michigan', 'California', 1),
#  ('California', 'Minnesota', 1),
#  ('Minnesota', 'California', 1),
#  ('California', 'Mississippi', 1),
#  ('Mississippi', 'California', 1),
#  ('California', 'Missouri', 0.7078445448224978),
#  ('Missouri', 'California', 0.7078445448224978),
#  ('California', 'Montana', 1),
#  ('Montana', 'California', 1),
#  ('California', 'Nebraska', 1),
#  ('Nebraska', 'California', 1),
#  ('California', 'Nevada', 0.9549996640451379),
#  ('Nevada', 'California', 0.9549996640451379),
#  ('California', 'New Hampshire', 1),
#  ('New Hampshire', 'California', 1),
#  ('California', 'New Jersey', 1),
#  ('New Jersey', 'California', 1),
#  ('California', 'New Mexico', 1),
#  ('New Mexico', 'California', 1),
#  ('California', 'New York', 0.8798198493008992),
#  ('New York', 'California', 0.8798198493008992),
#  ('California', 'North Carolina', 0.7574179328077947),
#  ('North Carolina', 'California', 0.7574179328077947),
#  ('California', 'North Dakota', 1),
#  ('North Dakota', 'California', 1),
#  ('California', 'Ohio', 0.7047784580752574),
#  ('Ohio', 'California', 0.7047784580752574),
#  ('California', 'Oklahoma', 0.7711532887580693),
#  ('Oklahoma', 'California', 0.7711532887580693),
#  ('California', 'Oregon', 0.7844097592698576),
#  ('Oregon', 'California', 0.7844097592698576),
#  ('California', 'Pennsylvania', 1),
#  ('Pennsylvania', 'California', 1),
#  ('California', 'Rhode Island', 1),
#  ('Rhode Island', 'California', 1),
#  ('California', 'South Carolina', 1),
#  ('South Carolina', 'California', 1),
#  ('California', 'South Dakota', 1),
#  ('South Dakota', 'California', 1),
#  ('California', 'Tennessee', 1),
#  ('Tennessee', 'California', 1),
#  ('California', 'Texas', 0.9771845343042149),
#  ('Texas', 'California', 0.9771845343042149),
#  ('California', 'Utah', 0.7801180373551585),
#  ('Utah', 'California', 0.7801180373551585),
#  ('California', 'Vermont', 1),
#  ('Vermont', 'California', 1),
#  ('California', 'Virginia', 0.7745151562823558),
#  ('Virginia', 'California', 0.7745151562823558),
#  ('California', 'Washington', 0.8049241214879672),
#  ('Washington', 'California', 0.8049241214879672),
#  ('California', 'West Virginia', 1),
#  ('West Virginia', 'California', 1),
#  ('California', 'Wisconsin', 1),
#  ('Wisconsin', 'California', 1),
#  ('California', 'Wyoming', 1),
#  ('Wyoming', 'California', 1),
#  ('California', 'Puerto Rico', 1),
#  ('Puerto Rico', 'California', 1),
#  ('Colorado', 'Connecticut', 1),
#  ('Connecticut', 'Colorado', 1),
#  ('Colorado', 'Delaware', 1),
#  ('Delaware', 'Colorado', 1),
#  ('Colorado', 'District of Columbia', 1),
#  ('District of Columbia', 'Colorado', 1),
#  ('Colorado', 'Florida', 0.971621360246988),
#  ('Florida', 'Colorado', 0.971621360246988),
#  ('Colorado', 'Georgia', 1),
#  ('Georgia', 'Colorado', 1),
#  ('Colorado', 'Hawaii', 0.504041160785644),
#  ('Hawaii', 'Colorado', 0.504041160785644),
#  ('Colorado', 'Idaho', 1),
#  ('Idaho', 'Colorado', 1),
#  ('Colorado', 'Illinois', 1),
#  ('Illinois', 'Colorado', 1),
#  ('Colorado', 'Indiana', 1),
#  ('Indiana', 'Colorado', 1),
#  ('Colorado', 'Iowa', 1),
#  ('Iowa', 'Colorado', 1),
#  ('Colorado', 'Kansas', 1),
#  ('Kansas', 'Colorado', 1),
#  ('Colorado', 'Kentucky', 1),
#  ('Kentucky', 'Colorado', 1),
#  ('Colorado', 'Louisiana', 1),
#  ('Louisiana', 'Colorado', 1),
#  ('Colorado', 'Maine', 1),
#  ('Maine', 'Colorado', 1),
#  ('Colorado', 'Maryland', 0.8889747780304846),
#  ('Maryland', 'Colorado', 0.8889747780304846),
#  ('Colorado', 'Massachusetts', 1),
#  ('Massachusetts', 'Colorado', 1),
#  ('Colorado', 'Michigan', 1),
#  ('Michigan', 'Colorado', 1),
#  ('Colorado', 'Minnesota', 1),
#  ('Minnesota', 'Colorado', 1),
#  ('Colorado', 'Mississippi', 1),
#  ('Mississippi', 'Colorado', 1),
#  ('Colorado', 'Missouri', 0.9644646395867533),
#  ('Missouri', 'Colorado', 0.9644646395867533),
#  ('Colorado', 'Montana', 1),
#  ('Montana', 'Colorado', 1),
#  ('Colorado', 'Nebraska', 1),
#  ('Nebraska', 'Colorado', 1),
#  ('Colorado', 'Nevada', 0.9645153197296248),
#  ('Nevada', 'Colorado', 0.9645153197296248),
#  ('Colorado', 'New Hampshire', 1),
#  ('New Hampshire', 'Colorado', 1),
#  ('Colorado', 'New Jersey', 1),
#  ('New Jersey', 'Colorado', 1),
#  ('Colorado', 'New Mexico', 1),
#  ('New Mexico', 'Colorado', 1),
#  ('Colorado', 'New York', 0.9775921518662357),
#  ('New York', 'Colorado', 0.9775921518662357),
#  ('Colorado', 'North Carolina', 0.9532184866691176),
#  ('North Carolina', 'Colorado', 0.9532184866691176),
#  ('Colorado', 'North Dakota', 1),
#  ('North Dakota', 'Colorado', 1),
#  ('Colorado', 'Ohio', 0.9621035280614008),
#  ('Ohio', 'Colorado', 0.9621035280614008),
#  ('Colorado', 'Oklahoma', 0.9804531690348123),
#  ('Oklahoma', 'Colorado', 0.9804531690348123),
#  ('Colorado', 'Oregon', 0.9901733583457138),
#  ('Oregon', 'Colorado', 0.9901733583457138),
#  ('Colorado', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Colorado', 1),
#  ('Colorado', 'Rhode Island', 1),
#  ('Rhode Island', 'Colorado', 1),
#  ('Colorado', 'South Carolina', 1),
#  ('South Carolina', 'Colorado', 1),
#  ('Colorado', 'South Dakota', 1),
#  ('South Dakota', 'Colorado', 1),
#  ('Colorado', 'Tennessee', 1),
#  ('Tennessee', 'Colorado', 1),
#  ('Colorado', 'Texas', 0.8909436727504227),
#  ('Texas', 'Colorado', 0.8909436727504227),
#  ('Colorado', 'Utah', 0.9906113783341056),
#  ('Utah', 'Colorado', 0.9906113783341056),
#  ('Colorado', 'Vermont', 1),
#  ('Vermont', 'Colorado', 1),
#  ('Colorado', 'Virginia', 0.959251930846975),
#  ('Virginia', 'Colorado', 0.959251930846975),
#  ('Colorado', 'Washington', 0.9886775311893318),
#  ('Washington', 'Colorado', 0.9886775311893318),
#  ('Colorado', 'West Virginia', 1),
#  ('West Virginia', 'Colorado', 1),
#  ('Colorado', 'Wisconsin', 1),
#  ('Wisconsin', 'Colorado', 1),
#  ('Colorado', 'Wyoming', 1),
#  ('Wyoming', 'Colorado', 1),
#  ('Colorado', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Colorado', 1),
#  ('Connecticut', 'Delaware', 1),
#  ('Delaware', 'Connecticut', 1),
#  ('Connecticut', 'District of Columbia', 1),
#  ('District of Columbia', 'Connecticut', 1),
#  ('Connecticut', 'Florida', 1),
#  ('Florida', 'Connecticut', 1),
#  ('Connecticut', 'Georgia', 1),
#  ('Georgia', 'Connecticut', 1),
#  ('Connecticut', 'Hawaii', 1),
#  ('Hawaii', 'Connecticut', 1),
#  ('Connecticut', 'Idaho', 1),
#  ('Idaho', 'Connecticut', 1),
#  ('Connecticut', 'Illinois', 1),
#  ('Illinois', 'Connecticut', 1),
#  ('Connecticut', 'Indiana', 1),
#  ('Indiana', 'Connecticut', 1),
#  ('Connecticut', 'Iowa', 1),
#  ('Iowa', 'Connecticut', 1),
#  ('Connecticut', 'Kansas', 1),
#  ('Kansas', 'Connecticut', 1),
#  ('Connecticut', 'Kentucky', 1),
#  ('Kentucky', 'Connecticut', 1),
#  ('Connecticut', 'Louisiana', 1),
#  ('Louisiana', 'Connecticut', 1),
#  ('Connecticut', 'Maine', 1),
#  ('Maine', 'Connecticut', 1),
#  ('Connecticut', 'Maryland', 1),
#  ('Maryland', 'Connecticut', 1),
#  ('Connecticut', 'Massachusetts', 1),
#  ('Massachusetts', 'Connecticut', 1),
#  ('Connecticut', 'Michigan', 1),
#  ('Michigan', 'Connecticut', 1),
#  ('Connecticut', 'Minnesota', 1),
#  ('Minnesota', 'Connecticut', 1),
#  ('Connecticut', 'Mississippi', 1),
#  ('Mississippi', 'Connecticut', 1),
#  ('Connecticut', 'Missouri', 1),
#  ('Missouri', 'Connecticut', 1),
#  ('Connecticut', 'Montana', 1),
#  ('Montana', 'Connecticut', 1),
#  ('Connecticut', 'Nebraska', 1),
#  ('Nebraska', 'Connecticut', 1),
#  ('Connecticut', 'Nevada', 1),
#  ('Nevada', 'Connecticut', 1),
#  ('Connecticut', 'New Hampshire', 1),
#  ('New Hampshire', 'Connecticut', 1),
#  ('Connecticut', 'New Jersey', 1),
#  ('New Jersey', 'Connecticut', 1),
#  ('Connecticut', 'New Mexico', 1),
#  ('New Mexico', 'Connecticut', 1),
#  ('Connecticut', 'New York', 1),
#  ('New York', 'Connecticut', 1),
#  ('Connecticut', 'North Carolina', 1),
#  ('North Carolina', 'Connecticut', 1),
#  ('Connecticut', 'North Dakota', 1),
#  ('North Dakota', 'Connecticut', 1),
#  ('Connecticut', 'Ohio', 1),
#  ('Ohio', 'Connecticut', 1),
#  ('Connecticut', 'Oklahoma', 1),
#  ('Oklahoma', 'Connecticut', 1),
#  ('Connecticut', 'Oregon', 1),
#  ('Oregon', 'Connecticut', 1),
#  ('Connecticut', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Connecticut', 1),
#  ('Connecticut', 'Rhode Island', 1),
#  ('Rhode Island', 'Connecticut', 1),
#  ('Connecticut', 'South Carolina', 1),
#  ('South Carolina', 'Connecticut', 1),
#  ('Connecticut', 'South Dakota', 1),
#  ('South Dakota', 'Connecticut', 1),
#  ('Connecticut', 'Tennessee', 1),
#  ('Tennessee', 'Connecticut', 1),
#  ('Connecticut', 'Texas', 1),
#  ('Texas', 'Connecticut', 1),
#  ('Connecticut', 'Utah', 1),
#  ('Utah', 'Connecticut', 1),
#  ('Connecticut', 'Vermont', 1),
#  ('Vermont', 'Connecticut', 1),
#  ('Connecticut', 'Virginia', 1),
#  ('Virginia', 'Connecticut', 1),
#  ('Connecticut', 'Washington', 1),
#  ('Washington', 'Connecticut', 1),
#  ('Connecticut', 'West Virginia', 1),
#  ('West Virginia', 'Connecticut', 1),
#  ('Connecticut', 'Wisconsin', 1),
#  ('Wisconsin', 'Connecticut', 1),
#  ('Connecticut', 'Wyoming', 1),
#  ('Wyoming', 'Connecticut', 1),
#  ('Connecticut', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Connecticut', 1),
#  ('Delaware', 'District of Columbia', 1),
#  ('District of Columbia', 'Delaware', 1),
#  ('Delaware', 'Florida', 1),
#  ('Florida', 'Delaware', 1),
#  ('Delaware', 'Georgia', 1),
#  ('Georgia', 'Delaware', 1),
#  ('Delaware', 'Hawaii', 1),
#  ('Hawaii', 'Delaware', 1),
#  ('Delaware', 'Idaho', 1),
#  ('Idaho', 'Delaware', 1),
#  ('Delaware', 'Illinois', 1),
#  ('Illinois', 'Delaware', 1),
#  ('Delaware', 'Indiana', 1),
#  ('Indiana', 'Delaware', 1),
#  ('Delaware', 'Iowa', 1),
#  ('Iowa', 'Delaware', 1),
#  ('Delaware', 'Kansas', 1),
#  ('Kansas', 'Delaware', 1),
#  ('Delaware', 'Kentucky', 1),
#  ('Kentucky', 'Delaware', 1),
#  ('Delaware', 'Louisiana', 1),
#  ('Louisiana', 'Delaware', 1),
#  ('Delaware', 'Maine', 1),
#  ('Maine', 'Delaware', 1),
#  ('Delaware', 'Maryland', 1),
#  ('Maryland', 'Delaware', 1),
#  ('Delaware', 'Massachusetts', 1),
#  ('Massachusetts', 'Delaware', 1),
#  ('Delaware', 'Michigan', 1),
#  ('Michigan', 'Delaware', 1),
#  ('Delaware', 'Minnesota', 1),
#  ('Minnesota', 'Delaware', 1),
#  ('Delaware', 'Mississippi', 1),
#  ('Mississippi', 'Delaware', 1),
#  ('Delaware', 'Missouri', 1),
#  ('Missouri', 'Delaware', 1),
#  ('Delaware', 'Montana', 1),
#  ('Montana', 'Delaware', 1),
#  ('Delaware', 'Nebraska', 1),
#  ('Nebraska', 'Delaware', 1),
#  ('Delaware', 'Nevada', 1),
#  ('Nevada', 'Delaware', 1),
#  ('Delaware', 'New Hampshire', 1),
#  ('New Hampshire', 'Delaware', 1),
#  ('Delaware', 'New Jersey', 1),
#  ('New Jersey', 'Delaware', 1),
#  ('Delaware', 'New Mexico', 1),
#  ('New Mexico', 'Delaware', 1),
#  ('Delaware', 'New York', 1),
#  ('New York', 'Delaware', 1),
#  ('Delaware', 'North Carolina', 1),
#  ('North Carolina', 'Delaware', 1),
#  ('Delaware', 'North Dakota', 1),
#  ('North Dakota', 'Delaware', 1),
#  ('Delaware', 'Ohio', 1),
#  ('Ohio', 'Delaware', 1),
#  ('Delaware', 'Oklahoma', 1),
#  ('Oklahoma', 'Delaware', 1),
#  ('Delaware', 'Oregon', 1),
#  ('Oregon', 'Delaware', 1),
#  ('Delaware', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Delaware', 1),
#  ('Delaware', 'Rhode Island', 1),
#  ('Rhode Island', 'Delaware', 1),
#  ('Delaware', 'South Carolina', 1),
#  ('South Carolina', 'Delaware', 1),
#  ('Delaware', 'South Dakota', 1),
#  ('South Dakota', 'Delaware', 1),
#  ('Delaware', 'Tennessee', 1),
#  ('Tennessee', 'Delaware', 1),
#  ('Delaware', 'Texas', 1),
#  ('Texas', 'Delaware', 1),
#  ('Delaware', 'Utah', 1),
#  ('Utah', 'Delaware', 1),
#  ('Delaware', 'Vermont', 1),
#  ('Vermont', 'Delaware', 1),
#  ('Delaware', 'Virginia', 1),
#  ('Virginia', 'Delaware', 1),
#  ('Delaware', 'Washington', 1),
#  ('Washington', 'Delaware', 1),
#  ('Delaware', 'West Virginia', 1),
#  ('West Virginia', 'Delaware', 1),
#  ('Delaware', 'Wisconsin', 1),
#  ('Wisconsin', 'Delaware', 1),
#  ('Delaware', 'Wyoming', 1),
#  ('Wyoming', 'Delaware', 1),
#  ('Delaware', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Delaware', 1),
#  ('District of Columbia', 'Florida', 1),
#  ('Florida', 'District of Columbia', 1),
#  ('District of Columbia', 'Georgia', 1),
#  ('Georgia', 'District of Columbia', 1),
#  ('District of Columbia', 'Hawaii', 1),
#  ('Hawaii', 'District of Columbia', 1),
#  ('District of Columbia', 'Idaho', 1),
#  ('Idaho', 'District of Columbia', 1),
#  ('District of Columbia', 'Illinois', 1),
#  ('Illinois', 'District of Columbia', 1),
#  ('District of Columbia', 'Indiana', 1),
#  ('Indiana', 'District of Columbia', 1),
#  ('District of Columbia', 'Iowa', 1),
#  ('Iowa', 'District of Columbia', 1),
#  ('District of Columbia', 'Kansas', 1),
#  ('Kansas', 'District of Columbia', 1),
#  ('District of Columbia', 'Kentucky', 1),
#  ('Kentucky', 'District of Columbia', 1),
#  ('District of Columbia', 'Louisiana', 1),
#  ('Louisiana', 'District of Columbia', 1),
#  ('District of Columbia', 'Maine', 1),
#  ('Maine', 'District of Columbia', 1),
#  ('District of Columbia', 'Maryland', 1),
#  ('Maryland', 'District of Columbia', 1),
#  ('District of Columbia', 'Massachusetts', 1),
#  ('Massachusetts', 'District of Columbia', 1),
#  ('District of Columbia', 'Michigan', 1),
#  ('Michigan', 'District of Columbia', 1),
#  ('District of Columbia', 'Minnesota', 1),
#  ('Minnesota', 'District of Columbia', 1),
#  ('District of Columbia', 'Mississippi', 1),
#  ('Mississippi', 'District of Columbia', 1),
#  ('District of Columbia', 'Missouri', 1),
#  ('Missouri', 'District of Columbia', 1),
#  ('District of Columbia', 'Montana', 1),
#  ('Montana', 'District of Columbia', 1),
#  ('District of Columbia', 'Nebraska', 1),
#  ('Nebraska', 'District of Columbia', 1),
#  ('District of Columbia', 'Nevada', 1),
#  ('Nevada', 'District of Columbia', 1),
#  ('District of Columbia', 'New Hampshire', 1),
#  ('New Hampshire', 'District of Columbia', 1),
#  ('District of Columbia', 'New Jersey', 1),
#  ('New Jersey', 'District of Columbia', 1),
#  ('District of Columbia', 'New Mexico', 1),
#  ('New Mexico', 'District of Columbia', 1),
#  ('District of Columbia', 'New York', 1),
#  ('New York', 'District of Columbia', 1),
#  ('District of Columbia', 'North Carolina', 1),
#  ('North Carolina', 'District of Columbia', 1),
#  ('District of Columbia', 'North Dakota', 1),
#  ('North Dakota', 'District of Columbia', 1),
#  ('District of Columbia', 'Ohio', 1),
#  ('Ohio', 'District of Columbia', 1),
#  ('District of Columbia', 'Oklahoma', 1),
#  ('Oklahoma', 'District of Columbia', 1),
#  ('District of Columbia', 'Oregon', 1),
#  ('Oregon', 'District of Columbia', 1),
#  ('District of Columbia', 'Pennsylvania', 1),
#  ('Pennsylvania', 'District of Columbia', 1),
#  ('District of Columbia', 'Rhode Island', 1),
#  ('Rhode Island', 'District of Columbia', 1),
#  ('District of Columbia', 'South Carolina', 1),
#  ('South Carolina', 'District of Columbia', 1),
#  ('District of Columbia', 'South Dakota', 1),
#  ('South Dakota', 'District of Columbia', 1),
#  ('District of Columbia', 'Tennessee', 1),
#  ('Tennessee', 'District of Columbia', 1),
#  ('District of Columbia', 'Texas', 1),
#  ('Texas', 'District of Columbia', 1),
#  ('District of Columbia', 'Utah', 1),
#  ('Utah', 'District of Columbia', 1),
#  ('District of Columbia', 'Vermont', 1),
#  ('Vermont', 'District of Columbia', 1),
#  ('District of Columbia', 'Virginia', 1),
#  ('Virginia', 'District of Columbia', 1),
#  ('District of Columbia', 'Washington', 1),
#  ('Washington', 'District of Columbia', 1),
#  ('District of Columbia', 'West Virginia', 1),
#  ('West Virginia', 'District of Columbia', 1),
#  ('District of Columbia', 'Wisconsin', 1),
#  ('Wisconsin', 'District of Columbia', 1),
#  ('District of Columbia', 'Wyoming', 1),
#  ('Wyoming', 'District of Columbia', 1),
#  ('District of Columbia', 'Puerto Rico', 1),
#  ('Puerto Rico', 'District of Columbia', 1),
#  ('Florida', 'Georgia', 1),
#  ('Georgia', 'Florida', 1),
#  ('Florida', 'Hawaii', 0.5009129764416302),
#  ('Hawaii', 'Florida', 0.5009129764416302),
#  ('Florida', 'Idaho', 1),
#  ('Idaho', 'Florida', 1),
#  ('Florida', 'Illinois', 1),
#  ('Illinois', 'Florida', 1),
#  ('Florida', 'Indiana', 1),
#  ('Indiana', 'Florida', 1),
#  ('Florida', 'Iowa', 1),
#  ('Iowa', 'Florida', 1),
#  ('Florida', 'Kansas', 1),
#  ('Kansas', 'Florida', 1),
#  ('Florida', 'Kentucky', 1),
#  ('Kentucky', 'Florida', 1),
#  ('Florida', 'Louisiana', 1),
#  ('Louisiana', 'Florida', 1),
#  ('Florida', 'Maine', 1),
#  ('Maine', 'Florida', 1),
#  ('Florida', 'Maryland', 0.9372311055310155),
#  ('Maryland', 'Florida', 0.9372311055310155),
#  ('Florida', 'Massachusetts', 1),
#  ('Massachusetts', 'Florida', 1),
#  ('Florida', 'Michigan', 1),
#  ('Michigan', 'Florida', 1),
#  ('Florida', 'Minnesota', 1),
#  ('Minnesota', 'Florida', 1),
#  ('Florida', 'Mississippi', 1),
#  ('Mississippi', 'Florida', 1),
#  ('Florida', 'Missouri', 0.9204737173120103),
#  ('Missouri', 'Florida', 0.9204737173120103),
#  ('Florida', 'Montana', 1),
#  ('Montana', 'Florida', 1),
#  ('Florida', 'Nebraska', 1),
#  ('Nebraska', 'Florida', 1),
#  ('Florida', 'Nevada', 0.9865105825119536),
#  ('Nevada', 'Florida', 0.9865105825119536),
#  ('Florida', 'New Hampshire', 1),
#  ('New Hampshire', 'Florida', 1),
#  ('Florida', 'New Jersey', 1),
#  ('New Jersey', 'Florida', 1),
#  ('Florida', 'New Mexico', 1),
#  ('New Mexico', 'Florida', 1),
#  ('Florida', 'New York', 0.9894249286453568),
#  ('New York', 'Florida', 0.9894249286453568),
#  ('Florida', 'North Carolina', 0.9568617640840212),
#  ('North Carolina', 'Florida', 0.9568617640840212),
#  ('Florida', 'North Dakota', 1),
#  ('North Dakota', 'Florida', 1),
#  ('Florida', 'Ohio', 0.9198095625905582),
#  ('Ohio', 'Florida', 0.9198095625905582),
#  ('Florida', 'Oklahoma', 0.9424953758573634),
#  ('Oklahoma', 'Florida', 0.9424953758573634),
#  ('Florida', 'Oregon', 0.93818828569172),
#  ('Oregon', 'Florida', 0.93818828569172),
#  ('Florida', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Florida', 1),
#  ('Florida', 'Rhode Island', 1),
#  ('Rhode Island', 'Florida', 1),
#  ('Florida', 'South Carolina', 1),
#  ('South Carolina', 'Florida', 1),
#  ('Florida', 'South Dakota', 1),
#  ('South Dakota', 'Florida', 1),
#  ('Florida', 'Tennessee', 1),
#  ('Tennessee', 'Florida', 1),
#  ('Florida', 'Texas', 0.952501606239596),
#  ('Texas', 'Florida', 0.952501606239596),
#  ('Florida', 'Utah', 0.9374481311554074),
#  ('Utah', 'Florida', 0.9374481311554074),
#  ('Florida', 'Vermont', 1),
#  ('Vermont', 'Florida', 1),
#  ('Florida', 'Virginia', 0.9571987236464019),
#  ('Virginia', 'Florida', 0.9571987236464019),
#  ('Florida', 'Washington', 0.9436837525444527),
#  ('Washington', 'Florida', 0.9436837525444527),
#  ('Florida', 'West Virginia', 1),
#  ('West Virginia', 'Florida', 1),
#  ('Florida', 'Wisconsin', 1),
#  ('Wisconsin', 'Florida', 1),
#  ('Florida', 'Wyoming', 1),
#  ('Wyoming', 'Florida', 1),
#  ('Florida', 'Puerto Rico', 1),
#  ('Puerto Rico', 'Florida', 1),
#  ('Georgia', 'Hawaii', 1),
#  ('Hawaii', 'Georgia', 1),
#  ('Georgia', 'Idaho', 1),
#  ('Idaho', 'Georgia', 1),
#  ('Georgia', 'Illinois', 1),
#  ('Illinois', 'Georgia', 1),
#  ('Georgia', 'Indiana', 1),
#  ('Indiana', 'Georgia', 1),
#  ('Georgia', 'Iowa', 1),
#  ('Iowa', 'Georgia', 1),
#  ('Georgia', 'Kansas', 1),
#  ('Kansas', 'Georgia', 1),
#  ('Georgia', 'Kentucky', 1),
#  ('Kentucky', 'Georgia', 1),
#  ('Georgia', 'Louisiana', 1),
#  ('Louisiana', 'Georgia', 1),
#  ('Georgia', 'Maine', 1),
#  ('Maine', 'Georgia', 1),
#  ('Georgia', 'Maryland', 1),
#  ('Maryland', 'Georgia', 1),
#  ('Georgia', 'Massachusetts', 1),
#  ('Massachusetts', 'Georgia', 1),
#  ('Georgia', 'Michigan', 1),
#  ('Michigan', 'Georgia', 1),
#  ('Georgia', 'Minnesota', 1),
#  ('Minnesota', 'Georgia', 1),
#  ('Georgia', 'Mississippi', 1),
#  ('Mississippi', 'Georgia', 1),
#  ('Georgia', 'Missouri', 1),
#  ('Missouri', 'Georgia', 1),
#  ('Georgia', 'Montana', 1),
#  ('Montana', 'Georgia', 1),
#  ('Georgia', 'Nebraska', 1),
#  ('Nebraska', 'Georgia', 1),
#  ('Georgia', 'Nevada', 1),
#  ('Nevada', 'Georgia', 1),
#  ('Georgia', 'New Hampshire', 1),
#  ('New Hampshire', 'Georgia', 1),
#  ('Georgia', 'New Jersey', 1),
#  ('New Jersey', 'Georgia', 1),
#  ('Georgia', 'New Mexico', 1),
#  ('New Mexico', 'Georgia', 1),
#  ('Georgia', 'New York', 1),
#  ('New York', 'Georgia', 1),
#  ('Georgia', 'North Carolina', 1),
#  ('North Carolina', 'Georgia', 1),
#  ('Georgia', 'North Dakota', 1),
#  ('North Dakota', 'Georgia', 1),
#  ('Georgia', 'Ohio', 1),
#  ('Ohio', 'Georgia', 1),
#  ('Georgia', 'Oklahoma', 1),
#  ('Oklahoma', 'Georgia', 1),
#  ('Georgia', 'Oregon', 1),
#  ('Oregon', 'Georgia', 1),
#  ('Georgia', 'Pennsylvania', 1),
#  ('Pennsylvania', 'Georgia', 1),
#  ('Georgia', 'Rhode Island', 1),
#  ('Rhode Island', 'Georgia', 1),
#  ('Georgia', 'South Carolina', 1),
#  ('South Carolina', 'Georgia', 1),
#  ('Georgia', 'South Dakota', 1),
#  ('South Dakota', 'Georgia', 1),
#  ('Georgia', 'Tennessee', 1),
#  ('Tennessee', 'Georgia', 1),
#  ('Georgia', 'Texas', 1),
#  ('Texas', 'Georgia', 1),
#  ('Georgia', 'Utah', 1),
#  ('Utah', 'Georgia', 1),
#  ('Georgia', 'Vermont', 1),
#  ('Vermont', 'Georgia', 1),
#  ...]

# %%
age_columns = ['Age0_18', 'Age_19_25', 'Age_26_34', 'Age_35_54', 'Age_55_64', 'Age_65_plus']
age_similarity = compute_cosine_similarity(data, age_columns)
age_similarity
# Out:
# /var/folders/bt/_bxgcdhj6z3_nfpmnzbyygj00000gn/T/ipykernel_68072/247036547.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data[similarity_columns].fillna(0, inplace=True)
# [('Alabama', 'Alaska', 0.9890460096780324),
#  ('Alaska', 'Alabama', 0.9890460096780324),
#  ('Alabama', 'Arizona', 0.9988976158758918),
#  ('Arizona', 'Alabama', 0.9988976158758918),
#  ('Alabama', 'Arkansas', 0.9995096916863627),
#  ('Arkansas', 'Alabama', 0.9995096916863627),
#  ('Alabama', 'California', 0.9960890669856749),
#  ('California', 'Alabama', 0.9960890669856749),
#  ('Alabama', 'Colorado', 0.9959837164034675),
#  ('Colorado', 'Alabama', 0.9959837164034675),
#  ('Alabama', 'Connecticut', 0.9983735900861956),
#  ('Connecticut', 'Alabama', 0.9983735900861956),
#  ('Alabama', 'Delaware', 0.9980908911167148),
#  ('Delaware', 'Alabama', 0.9980908911167148),
#  ('Alabama', 'District of Columbia', 0.9583185024907371),
#  ('District of Columbia', 'Alabama', 0.9583185024907371),
#  ('Alabama', 'Florida', 0.9942481155288823),
#  ('Florida', 'Alabama', 0.9942481155288823),
#  ('Alabama', 'Georgia', 0.9957790780355167),
#  ('Georgia', 'Alabama', 0.9957790780355167),
#  ('Alabama', 'Hawaii', 0.9976775338843017),
#  ('Hawaii', 'Alabama', 0.9976775338843017),
#  ('Alabama', 'Idaho', 0.9963529442086612),
#  ('Idaho', 'Alabama', 0.9963529442086612),
#  ('Alabama', 'Illinois', 0.9988461786032495),
#  ('Illinois', 'Alabama', 0.9988461786032495),
#  ('Alabama', 'Indiana', 0.9993027706710573),
#  ('Indiana', 'Alabama', 0.9993027706710573),
#  ('Alabama', 'Iowa', 0.9996986187893945),
#  ('Iowa', 'Alabama', 0.9996986187893945),
#  ('Alabama', 'Kansas', 0.9981108713364403),
#  ('Kansas', 'Alabama', 0.9981108713364403),
#  ('Alabama', 'Kentucky', 0.9997874455622177),
#  ('Kentucky', 'Alabama', 0.9997874455622177),
#  ('Alabama', 'Louisiana', 0.9984157598168532),
#  ('Louisiana', 'Alabama', 0.9984157598168532),
#  ('Alabama', 'Maine', 0.9902628606349387),
#  ('Maine', 'Alabama', 0.9902628606349387),
#  ('Alabama', 'Maryland', 0.9981820487462936),
#  ('Maryland', 'Alabama', 0.9981820487462936),
#  ('Alabama', 'Massachusetts', 0.9971455326118238),
#  ('Massachusetts', 'Alabama', 0.9971455326118238),
#  ('Alabama', 'Michigan', 0.9995659773474094),
#  ('Michigan', 'Alabama', 0.9995659773474094),
#  ('Alabama', 'Minnesota', 0.9990526580946041),
#  ('Minnesota', 'Alabama', 0.9990526580946041),
#  ('Alabama', 'Mississippi', 0.9986440066662324),
#  ('Mississippi', 'Alabama', 0.9986440066662324),
#  ('Alabama', 'Missouri', 0.9996893581833974),
#  ('Missouri', 'Alabama', 0.9996893581833974),
#  ('Alabama', 'Montana', 0.9979730655012303),
#  ('Montana', 'Alabama', 0.9979730655012303),
#  ('Alabama', 'Nebraska', 0.9978563667787517),
#  ('Nebraska', 'Alabama', 0.9978563667787517),
#  ('Alabama', 'Nevada', 0.9983900951224938),
#  ('Nevada', 'Alabama', 0.9983900951224938),
#  ('Alabama', 'New Hampshire', 0.9940143136590024),
#  ('New Hampshire', 'Alabama', 0.9940143136590024),
#  ('Alabama', 'New Jersey', 0.9985177111013402),
#  ('New Jersey', 'Alabama', 0.9985177111013402),
#  ('Alabama', 'New Mexico', 0.9988032411182731),
#  ('New Mexico', 'Alabama', 0.9988032411182731),
#  ('Alabama', 'New York', 0.9976966771973915),
#  ('New York', 'Alabama', 0.9976966771973915),
#  ('Alabama', 'North Carolina', 0.9993513730404212),
#  ('North Carolina', 'Alabama', 0.9993513730404212),
#  ('Alabama', 'North Dakota', 0.9963772636472236),
#  ('North Dakota', 'Alabama', 0.9963772636472236),
#  ('Alabama', 'Ohio', 0.9998000300211687),
#  ('Ohio', 'Alabama', 0.9998000300211687),
#  ('Alabama', 'Oklahoma', 0.9977951372749533),
#  ('Oklahoma', 'Alabama', 0.9977951372749533),
#  ('Alabama', 'Oregon', 0.9982351938177966),
#  ('Oregon', 'Alabama', 0.9982351938177966),
#  ('Alabama', 'Pennsylvania', 0.9982827934837946),
#  ('Pennsylvania', 'Alabama', 0.9982827934837946),
#  ('Alabama', 'Rhode Island', 0.9972879587863703),
#  ('Rhode Island', 'Alabama', 0.9972879587863703),
#  ('Alabama', 'South Carolina', 0.9995787700189511),
#  ('South Carolina', 'Alabama', 0.9995787700189511),
#  ('Alabama', 'South Dakota', 0.997919493722197),
#  ('South Dakota', 'Alabama', 0.997919493722197),
#  ('Alabama', 'Tennessee', 0.9995505777407551),
#  ('Tennessee', 'Alabama', 0.9995505777407551),
#  ('Alabama', 'Texas', 0.9897474377461211),
#  ('Texas', 'Alabama', 0.9897474377461211),
#  ('Alabama', 'Utah', 0.9729242929574071),
#  ('Utah', 'Alabama', 0.9729242929574071),
#  ('Alabama', 'Vermont', 0.9923411882246399),
#  ('Vermont', 'Alabama', 0.9923411882246399),
#  ('Alabama', 'Virginia', 0.9988528384074654),
#  ('Virginia', 'Alabama', 0.9988528384074654),
#  ('Alabama', 'Washington', 0.9980562559095794),
#  ('Washington', 'Alabama', 0.9980562559095794),
#  ('Alabama', 'West Virginia', 0.9958212197738182),
#  ('West Virginia', 'Alabama', 0.9958212197738182),
#  ('Alabama', 'Wisconsin', 0.999709908869895),
#  ('Wisconsin', 'Alabama', 0.999709908869895),
#  ('Alabama', 'Wyoming', 0.9979748359158608),
#  ('Wyoming', 'Alabama', 0.9979748359158608),
#  ('Alabama', 'Puerto Rico', 0.9946642800772774),
#  ('Puerto Rico', 'Alabama', 0.9946642800772774),
#  ('Alaska', 'Arizona', 0.9878192964549785),
#  ('Arizona', 'Alaska', 0.9878192964549785),
#  ('Alaska', 'Arkansas', 0.9904437441264904),
#  ('Arkansas', 'Alaska', 0.9904437441264904),
#  ('Alaska', 'California', 0.9957512667972234),
#  ('California', 'Alaska', 0.9957512667972234),
#  ('Alaska', 'Colorado', 0.9954517366721866),
#  ('Colorado', 'Alaska', 0.9954517366721866),
#  ('Alaska', 'Connecticut', 0.9842645743632498),
#  ('Connecticut', 'Alaska', 0.9842645743632498),
#  ('Alaska', 'Delaware', 0.9803191345740894),
#  ('Delaware', 'Alaska', 0.9803191345740894),
#  ('Alaska', 'District of Columbia', 0.965681595243057),
#  ('District of Columbia', 'Alaska', 0.965681595243057),
#  ('Alaska', 'Florida', 0.9692711360035347),
#  ('Florida', 'Alaska', 0.9692711360035347),
#  ('Alaska', 'Georgia', 0.9969772612126191),
#  ('Georgia', 'Alaska', 0.9969772612126191),
#  ('Alaska', 'Hawaii', 0.9818690686503471),
#  ('Hawaii', 'Alaska', 0.9818690686503471),
#  ('Alaska', 'Idaho', 0.9935459295640321),
#  ('Arizona', 'Maryland', 0.9955835690954674),
#  ('Maryland', 'Arizona', 0.9955835690954674),
#  ('Arizona', 'Massachusetts', 0.9947311912790685),
#  ('Massachusetts', 'Arizona', 0.9947311912790685),
#  ('Arizona', 'Michigan', 0.9977807874393139),
#  ('Michigan', 'Arizona', 0.9977807874393139),
#  ('Arizona', 'Minnesota', 0.9975709817144448),
#  ('Minnesota', 'Arizona', 0.9975709817144448),
#  ('Arizona', 'Mississippi', 0.998042957999467),
#  ('Mississippi', 'Arizona', 0.998042957999467),
#  ('Arizona', 'Missouri', 0.9989313760542933),
#  ('Missouri', 'Arizona', 0.9989313760542933),
#  ('Arizona', 'Montana', 0.996874096380887),
#  ('Montana', 'Arizona', 0.996874096380887),
#  ('Arizona', 'Nebraska', 0.998063130893),
#  ('Nebraska', 'Arizona', 0.998063130893),
#  ('Arizona', 'Nevada', 0.9973585716346064),
#  ('Nevada', 'Arizona', 0.9973585716346064),
#  ('Arizona', 'New Hampshire', 0.9896337706907047),
#  ('New Hampshire', 'Arizona', 0.9896337706907047),
#  ('Arizona', 'New Jersey', 0.9958074163384296),
#  ('New Jersey', 'Arizona', 0.9958074163384296),
#  ('Arizona', 'New Mexico', 0.9992843113205022),
#  ('New Mexico', 'Arizona', 0.9992843113205022),
#  ('Arizona', 'New York', 0.9960073093988449),
#  ('New York', 'Arizona', 0.9960073093988449),
#  ('Arizona', 'North Carolina', 0.9978334919624102),
#  ('North Carolina', 'Arizona', 0.9978334919624102),
#  ('Arizona', 'North Dakota', 0.9964372204432094),
#  ('North Dakota', 'Arizona', 0.9964372204432094),
#  ('Arizona', 'Ohio', 0.9983782377117467),
#  ('Ohio', 'Arizona', 0.9983782377117467),
#  ('Arizona', 'Oklahoma', 0.9981958309929675),
#  ('Oklahoma', 'Arizona', 0.9981958309929675),
#  ('Arizona', 'Oregon', 0.9971479389686821),
#  ('Oregon', 'Arizona', 0.9971479389686821),
#  ('Arizona', 'Pennsylvania', 0.9965110100347138),
#  ('Pennsylvania', 'Arizona', 0.9965110100347138),
#  ('Arizona', 'Rhode Island', 0.9948095430124657),
#  ('Rhode Island', 'Arizona', 0.9948095430124657),
#  ('Arizona', 'South Carolina', 0.9985477013388472),
#  ('South Carolina', 'Arizona', 0.9985477013388472),
#  ('Arizona', 'South Dakota', 0.9984605189073583),
#  ('South Dakota', 'Arizona', 0.9984605189073583),
#  ('Arizona', 'Tennessee', 0.9982054523895239),
#  ('Tennessee', 'Arizona', 0.9982054523895239),
#  ('Arizona', 'Texas', 0.9898301893518707),
#  ('Texas', 'Arizona', 0.9898301893518707),
#  ('Arizona', 'Utah', 0.9759899089294567),
#  ('Utah', 'Arizona', 0.9759899089294567),
#  ('Arizona', 'Vermont', 0.9890700088419759),
#  ('Vermont', 'Arizona', 0.9890700088419759),
#  ('Arizona', 'Virginia', 0.9968794915870429),
#  ('Virginia', 'Arizona', 0.9968794915870429),
#  ('Arizona', 'Washington', 0.9967592515861661),
#  ('Washington', 'Arizona', 0.9967592515861661),
#  ('Arizona', 'West Virginia', 0.9938869846526016),
#  ('District of Columbia', 'California', 0.9749156263127813),
#  ('California', 'Florida', 0.9850663242235932),
#  ('Florida', 'California', 0.9850663242235932),
#  ('California', 'Georgia', 0.9985916273721145),
#  ('Georgia', 'California', 0.9985916273721145),
#  ('California', 'Hawaii', 0.9921719685610308),
#  ('Hawaii', 'California', 0.9921719685610308),
#  ('California', 'Idaho', 0.9943067784938251),
#  ('Idaho', 'California', 0.9943067784938251),
#  ('California', 'Illinois', 0.9989852124342059),
#  ('Illinois', 'California', 0.9989852124342059),
#  ('California', 'Indiana', 0.9978553501798515),
#  ('Indiana', 'California', 0.9978553501798515),
#  ('California', 'Iowa', 0.9957419575662475),
#  ('Iowa', 'California', 0.9957419575662475),
#  ('California', 'Kansas', 0.9962882010346007),
#  ('Kansas', 'California', 0.9962882010346007),
#  ('California', 'Kentucky', 0.9970473768439913),
#  ('Kentucky', 'California', 0.9970473768439913),
#  ('California', 'Louisiana', 0.9980769960451903),
#  ('Louisiana', 'California', 0.9980769960451903),
#  ('California', 'Maine', 0.9789683161266901),
#  ('Maine', 'California', 0.9789683161266901),
#  ('California', 'Maryland', 0.9983002068336961),
#  ('Maryland', 'California', 0.9983002068336961),
#  ('California', 'Massachusetts', 0.9958361916693318),
#  ('Massachusetts', 'California', 0.9958361916693318),
#  ('California', 'Michigan', 0.994883359199249),
#  ('Michigan', 'California', 0.994883359199249),
#  ('California', 'Minnesota', 0.998313079264539),
#  ('Minnesota', 'California', 0.998313079264539),
#  ('California', 'Mississippi', 0.995634700839615),
#  ('Mississippi', 'California', 0.995634700839615),
#  ('California', 'Missouri', 0.9964297279753642),
#  ('Missouri', 'California', 0.9964297279753642),
#  ('California', 'Montana', 0.9902009921143593),
#  ('Montana', 'California', 0.9902009921143593),
#  ('California', 'Nebraska', 0.9969272449823277),
#  ('Nebraska', 'California', 0.9969272449823277),
#  ('California', 'Nevada', 0.9990198103514896),
#  ('Nevada', 'California', 0.9990198103514896),
#  ('California', 'New Hampshire', 0.9871436501385037),
#  ('New Hampshire', 'California', 0.9871436501385037),
#  ('California', 'New Jersey', 0.9970277730527732),
#  ('New Jersey', 'California', 0.9970277730527732),
#  ('California', 'New Mexico', 0.9939850711480485),
#  ('New Mexico', 'California', 0.9939850711480485),
#  ('California', 'New York', 0.9974431136579561),
#  ('New York', 'California', 0.9974431136579561),
#  ('California', 'North Carolina', 0.997564798837965),
#  ('North Carolina', 'California', 0.997564798837965),
#  ('California', 'North Dakota', 0.9972897742642083),
#  ('North Dakota', 'California', 0.9972897742642083),
#  ('California', 'Ohio', 0.9958705624249048),
#  ('Ohio', 'California', 0.9958705624249048),
#  ('California', 'Oklahoma', 0.9968870842195757),
#  ('Oklahoma', 'California', 0.9968870842195757),
#  ('California', 'Oregon', 0.9954785402917992),
#  ('Oregon', 'California', 0.9954785402917992),
#  ('California', 'Pennsylvania', 0.9923220285088756),
#  ('Pennsylvania', 'California', 0.9923220285088756),
#  ('California', 'Rhode Island', 0.9938582348426411),
#  ('Rhode Island', 'California', 0.9938582348426411),
#  ('California', 'South Carolina', 0.9944586009632478),
#  ('South Carolina', 'California', 0.9944586009632478),
#  ('California', 'South Dakota', 0.9946136210466328),
#  ('South Dakota', 'California', 0.9946136210466328),
#  ('California', 'Tennessee', 0.9977678941474848),
#  ('Tennessee', 'California', 0.9977678941474848),
#  ('California', 'Texas', 0.9959245682011613),
#  ('Texas', 'California', 0.9959245682011613),
#  ('California', 'Utah', 0.9815217339917448),
#  ('Utah', 'California', 0.9815217339917448),
#  ('California', 'Vermont', 0.9821938106800561),
#  ('Vermont', 'California', 0.9821938106800561),
#  ('California', 'Virginia', 0.9984458839970781),
#  ('Virginia', 'California', 0.9984458839970781),
#  ('California', 'Washington', 0.999086546282756),
#  ('Washington', 'California', 0.999086546282756),
#  ('California', 'West Virginia', 0.985515678910743),
#  ('West Virginia', 'California', 0.985515678910743),
#  ('California', 'Wisconsin', 0.9952847921472974),
#  ('Wisconsin', 'California', 0.9952847921472974),
#  ('California', 'Wyoming', 0.9947166198641542),
#  ('Wyoming', 'California', 0.9947166198641542),
#  ('California', 'Puerto Rico', 0.9859559442568502),
#  ('Puerto Rico', 'California', 0.9859559442568502),
#  ('Colorado', 'Connecticut', 0.994745311849304),
#  ('Connecticut', 'Colorado', 0.994745311849304),
#  ('Colorado', 'Delaware', 0.9920013242663661),
#  ('Delaware', 'Colorado', 0.9920013242663661),
#  ('Colorado', 'District of Columbia', 0.9765423964089073),
#  ('District of Columbia', 'Colorado', 0.9765423964089073),
#  ('Colorado', 'Florida', 0.9856463570910851),
#  ('Florida', 'Colorado', 0.9856463570910851),
#  ('Colorado', 'Georgia', 0.9980356893951907),
#  ('Georgia', 'Colorado', 0.9980356893951907),
#  ('Colorado', 'Hawaii', 0.9928441411300187),
#  ('Hawaii', 'Colorado', 0.9928441411300187),
#  ('Colorado', 'Idaho', 0.9932894093498443),
#  ('Idaho', 'Colorado', 0.9932894093498443),
#  ('Colorado', 'Illinois', 0.9990494923133356),
#  ('Illinois', 'Colorado', 0.9990494923133356),
#  ('Colorado', 'Indiana', 0.9975208342261609),
#  ('Indiana', 'Colorado', 0.9975208342261609),
#  ('Colorado', 'Iowa', 0.9955301624783482),
#  ('Iowa', 'Colorado', 0.9955301624783482),
#  ('Colorado', 'Kansas', 0.9956505781287004),
#  ('Kansas', 'Colorado', 0.9956505781287004),
#  ('Colorado', 'Kentucky', 0.9970672348888056),
#  ('Kentucky', 'Colorado', 0.9970672348888056),
#  ('Colorado', 'Louisiana', 0.9976248445288801),
#  ('Louisiana', 'Colorado', 0.9976248445288801),
#  ('Colorado', 'Maine', 0.9808298819363376),
#  ('Maine', 'Colorado', 0.9808298819363376),
#  ('Colorado', 'Maryland', 0.998719129210643),
#  ('Maryland', 'Colorado', 0.998719129210643),
#  ('Colorado', 'Massachusetts', 0.9967972758785991),
#  ('Massachusetts', 'Colorado', 0.9967972758785991),
#  ('Colorado', 'Michigan', 0.9951804115660126),
#  ('Michigan', 'Colorado', 0.9951804115660126),
#  ('Colorado', 'Minnesota', 0.998547299663973),
#  ('Minnesota', 'Colorado', 0.998547299663973),
#  ('Colorado', 'Mississippi', 0.9947677590388264),
#  ('Mississippi', 'Colorado', 0.9947677590388264),
#  ('Colorado', 'Missouri', 0.9966233022469075),
#  ('Missouri', 'Colorado', 0.9966233022469075),
#  ('Colorado', 'Montana', 0.9906245442589464),
#  ('Montana', 'Colorado', 0.9906245442589464),
#  ('Colorado', 'Nebraska', 0.9964873181765188),
#  ('Nebraska', 'Colorado', 0.9964873181765188),
#  ('Colorado', 'Nevada', 0.9989957307103455),
#  ('Nevada', 'Colorado', 0.9989957307103455),
#  ('Colorado', 'New Hampshire', 0.9888073219966992),
#  ('New Hampshire', 'Colorado', 0.9888073219966992),
#  ('Colorado', 'New Jersey', 0.9974079189650688),
#  ('New Jersey', 'Colorado', 0.9974079189650688),
#  ('Colorado', 'New Mexico', 0.9935767409757266),
#  ('New Mexico', 'Colorado', 0.9935767409757266),
#  ('Colorado', 'New York', 0.9980013550817639),
#  ('New York', 'Colorado', 0.9980013550817639),
#  ('Colorado', 'North Carolina', 0.9975478621361092),
#  ('North Carolina', 'Colorado', 0.9975478621361092),
#  ('Colorado', 'North Dakota', 0.9970967391574411),
#  ('North Dakota', 'Colorado', 0.9970967391574411),
#  ('Colorado', 'Ohio', 0.9961714395082),
#  ('Ohio', 'Colorado', 0.9961714395082),
#  ('Colorado', 'Oklahoma', 0.996291876239782),
#  ('Oklahoma', 'Colorado', 0.996291876239782),
#  ('Colorado', 'Oregon', 0.9961234764740896),
#  ('Oregon', 'Colorado', 0.9961234764740896),
#  ('Colorado', 'Pennsylvania', 0.9931430726475082),
#  ('Pennsylvania', 'Colorado', 0.9931430726475082),
#  ('Colorado', 'Rhode Island', 0.9947233567460367),
#  ('Rhode Island', 'Colorado', 0.9947233567460367),
#  ('Colorado', 'South Carolina', 0.9946201431206798),
#  ('South Carolina', 'Colorado', 0.9946201431206798),
#  ('Colorado', 'South Dakota', 0.9945111713135584),
#  ('South Dakota', 'Colorado', 0.9945111713135584),
#  ('Colorado', 'Tennessee', 0.9979269110192626),
#  ('Tennessee', 'Colorado', 0.9979269110192626),
#  ('Colorado', 'Texas', 0.994744298846934),
#  ('Texas', 'Colorado', 0.994744298846934),
#  ('Colorado', 'Utah', 0.9788282253795716),
#  ('Utah', 'Colorado', 0.9788282253795716),
#  ('Colorado', 'Vermont', 0.9836095773272543),
#  ('Vermont', 'Colorado', 0.9836095773272543),
#  ('Colorado', 'Virginia', 0.9985700300239315),
#  ('Virginia', 'Colorado', 0.9985700300239315),
#  ('Colorado', 'Washington', 0.9994479702201361),
#  ('Washington', 'Colorado', 0.9994479702201361),
#  ('Colorado', 'West Virginia', 0.9861084740283893),
#  ('West Virginia', 'Colorado', 0.9861084740283893),
#  ('Colorado', 'Wisconsin', 0.995642782114617),
#  ('Wisconsin', 'Colorado', 0.995642782114617),
#  ('Colorado', 'Wyoming', 0.9949042403096279),
#  ('Wyoming', 'Colorado', 0.9949042403096279),
#  ('Colorado', 'Puerto Rico', 0.9857479003959005),
#  ('Puerto Rico', 'Colorado', 0.9857479003959005),
#  ('Florida', 'Utah', 0.9459872108855524),
#  ('Utah', 'Florida', 0.9459872108855524),
#  ('Florida', 'Vermont', 0.9974269369580159),
#  ('Vermont', 'Florida', 0.9974269369580159),
#  ('Florida', 'Virginia', 0.9914028855668388),
#  ('Virginia', 'Florida', 0.9914028855668388),
#  ('Florida', 'Washington', 0.9905347521495182),
#  ('Washington', 'Florida', 0.9905347521495182),
#  ('Florida', 'West Virginia', 0.9988840607888202),
#  ('West Virginia', 'Florida', 0.9988840607888202),
#  ('Florida', 'Wisconsin', 0.994870624130024),
#  ('Wisconsin', 'Florida', 0.994870624130024),
#  ('Florida', 'Wyoming', 0.9888895681953819),
#  ('Wyoming', 'Florida', 0.9888895681953819),
#  ('Florida', 'Puerto Rico', 0.9988974617393175),
#  ('Puerto Rico', 'Florida', 0.9988974617393175),
#  ('Georgia', 'Hawaii', 0.9901454579187808),
#  ('Hawaii', 'Georgia', 0.9901454579187808),
#  ('Georgia', 'Idaho', 0.9963656908482714),
#  ('Idaho', 'Georgia', 0.9963656908482714),
#  ('Georgia', 'Illinois', 0.9983651420836105),
#  ('Illinois', 'Georgia', 0.9983651420836105),
#  ('Georgia', 'Indiana', 0.998215398823467),
#  ('Indiana', 'Georgia', 0.998215398823467),
#  ('Georgia', 'Iowa', 0.9957862003770893),
#  ('Iowa', 'Georgia', 0.9957862003770893),
#  ('Georgia', 'Kansas', 0.9970818161423496),
#  ('Kansas', 'Georgia', 0.9970818161423496),
#  ('Georgia', 'Kentucky', 0.9971417562106807),
#  ('Kentucky', 'Georgia', 0.9971417562106807),
#  ('Georgia', 'Louisiana', 0.9983386003365925),
#  ('Louisiana', 'Georgia', 0.9983386003365925),
#  ('Georgia', 'Maine', 0.976146463045187),
#  ('Maine', 'Georgia', 0.976146463045187),
#  ('Georgia', 'Maryland', 0.9978277701602695),
#  ('Maryland', 'Georgia', 0.9978277701602695),
#  ('Georgia', 'Massachusetts', 0.9928611654476835),
#  ('Massachusetts', 'Georgia', 0.9928611654476835),
#  ('Georgia', 'Michigan', 0.9936556159478086),
#  ('Michigan', 'Georgia', 0.9936556159478086),
#  ('Georgia', 'Minnesota', 0.9979240090331257),
#  ('Minnesota', 'Georgia', 0.9979240090331257),
#  ('Georgia', 'Mississippi', 0.9973272145121641),
#  ('Mississippi', 'Georgia', 0.9973272145121641),
#  ('Georgia', 'Missouri', 0.9955215055731037),
#  ('Missouri', 'Georgia', 0.9955215055731037),
#  ('Georgia', 'Montana', 0.9881815464192445),
#  ('Montana', 'Georgia', 0.9881815464192445),
#  ('Georgia', 'Nebraska', 0.9972773602953989),
#  ('Nebraska', 'Georgia', 0.9972773602953989),
#  ('Georgia', 'Nevada', 0.9980314157962588),
#  ('Nevada', 'Georgia', 0.9980314157962588),
#  ('Georgia', 'New Hampshire', 0.9846988914408186),
#  ('New Hampshire', 'Georgia', 0.9846988914408186),
#  ('Georgia', 'New Jersey', 0.9968549492332903),
#  ('New Jersey', 'Georgia', 0.9968549492332903),
#  ('Georgia', 'New Mexico', 0.9935332166786774),
#  ('New Mexico', 'Georgia', 0.9935332166786774),
#  ('Georgia', 'New York', 0.9944666463971773),
#  ('New York', 'Georgia', 0.9944666463971773),
#  ('Georgia', 'North Carolina', 0.9975421631112542),
#  ('North Carolina', 'Georgia', 0.9975421631112542),
#  ('Georgia', 'North Dakota', 0.9951029734361644),
#  ('North Dakota', 'Georgia', 0.9951029734361644),
#  ('Georgia', 'Ohio', 0.9950611284997033),
#  ('Ohio', 'Georgia', 0.9950611284997033),
#  ('Georgia', 'Oklahoma', 0.9974699207898097),
#  ('Oklahoma', 'Georgia', 0.9974699207898097),
#  ('Georgia', 'Oregon', 0.9926663352067006),
#  ('Oregon', 'Georgia', 0.9926663352067006),
#  ('Georgia', 'Pennsylvania', 0.9902541294629441),
#  ('Pennsylvania', 'Georgia', 0.9902541294629441),
#  ('Georgia', 'Rhode Island', 0.9906052525430608),
#  ('Rhode Island', 'Georgia', 0.9906052525430608),
#  ('Georgia', 'South Carolina', 0.9935113540887263),
#  ('South Carolina', 'Georgia', 0.9935113540887263),
#  ('Georgia', 'South Dakota', 0.9943200531192122),
#  ('South Dakota', 'Georgia', 0.9943200531192122),
#  ('Georgia', 'Tennessee', 0.9971204125632386),
#  ('Tennessee', 'Georgia', 0.9971204125632386),
#  ('Georgia', 'Texas', 0.997803337382795),
#  ('Texas', 'Georgia', 0.997803337382795),
#  ('Georgia', 'Utah', 0.9852989784150998),
#  ('Utah', 'Georgia', 0.9852989784150998),
#  ('Georgia', 'Vermont', 0.9789276921557953),
#  ('Vermont', 'Georgia', 0.9789276921557953),
#  ...]

# %% [markdown]
# __A9.__ _(3 points)_ Next, we would like to investigate which locations are the most or least similar given these different types of demographics. To support these investigations, write a function called `get_min_max_similarity`. The function should take a `similarity_list`, which is the output from the `compute_cosite_similarity()` method you wrote in A8. The function should return two values `min_similarity` and `max_similarity`. These correspond to the entries from the provided `similarity_list` that have the smallest and largest similarity respectively.
#
# For example `min_similarity` and `max_similarity` will have the format `(<location 1>, <location 2>, <cosine similarity>)`.

# %%
# A9:Function(3/3)

def get_min_max_similarity(similarity_list):
    
    #---Your code starts here
    min_similarity = min(similarity_list, key=lambda x: x[2])
    max_similarity = max(similarity_list, key=lambda x: x[2])
    #---Your code ends here
    
    return min_similarity, max_similarity

# %% [markdown]
# To test this function, let's apply it to compare states in terms of both race and age similarity.

# %%
# A9:SanityCheck

min_race_similarity, max_race_similarity = get_min_max_similarity(race_similarity)
print("The locations with least similar race demographics: {}".format(min_race_similarity))
print("The locations with most similar race demographics: {}".format(max_race_similarity))
# Out:
# The locations with least similar race demographics: ('Hawaii', 'Missouri', 0.454507268860179)
# The locations with most similar race demographics: ('Alabama', 'Alaska', 1)

# %%
# A9:SanityCheck

min_age_similarity, max_age_similarity = get_min_max_similarity(age_similarity)
print("The locations with least similar age demographics: {}".format(min_age_similarity))
print("The locations with most similar age demographics: {}".format(max_age_similarity))
# Out:
# The locations with least similar age demographics: ('Maine', 'Utah', 0.9321725437407274)
# The locations with most similar age demographics: ('Nebraska', 'Oklahoma', 0.9999533208314443)
